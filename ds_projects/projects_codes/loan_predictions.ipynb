# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline


df=pd.read_csv("G:\DATASCIENCE\ds_projects\csvfiles\loan_preditions.csv")

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
print(df.shape)
df.head(5)
# Out:
# (614, 13)
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
sns.countplot(x="Education", data=df )
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
df.value_counts('Property_Area')
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# dtype: int64

# %%
sns.countplot(x="Credit_History", data = df)
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %% [markdown]
# #### Distribution analysis

# %%
df.hist("ApplicantIncome", bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'ApplicantIncome'}>]], dtype=object)

# %%
df.value_counts([ "ApplicantIncome"])
# Out:
# ApplicantIncome
# 2500               9
# 2600               6
# 4583               6
# 6000               6
# 3750               5
#                   ..
# 4917               1
# 4923               1
# 4931               1
# 4945               1
# 150                1
# Length: 505, dtype: int64

# %%
df.boxplot('ApplicantIncome')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('ApplicantIncome','Education')
# Out:
# <AxesSubplot:title={'center':'ApplicantIncome'}, xlabel='Education'>

# %%
sns.countplot(x="Married", data=df)
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
df.hist("LoanAmount", bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'LoanAmount'}>]], dtype=object)

# %%
df.boxplot('LoanAmount', figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.boxplot('LoanAmount', 'Loan_Status', figsize=(15,7))
# Out:
# <AxesSubplot:title={'center':'LoanAmount'}, xlabel='Loan_Status'>

# %% [markdown]
# #### Categorical variable analysis

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# visualizing regression plot

sns.lmplot(x="ApplicantIncome", y="LoanAmount", data=df)

# %%
sns.lmplot(x="ApplicantIncome", y="LoanAmount",col="Gender", data=df)

# %%
temp1 = df.value_counts(['Credit_History'], ascending=True) 
temp2 = df.pivot_table(values='Loan_Status',index=['Credit_History'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean()) 
print ('Frequency Table for Credit History:')
print (temp1) 
print ('\nProbility of getting loan for each Credit History class:') 
print (temp2)
# Out:
# Frequency Table for Credit History:
# Credit_History
# 0.0                89
# 1.0               475
# dtype: int64
#
# Probility of getting loan for each Credit History class:
#                 Loan_Status
# Credit_History
# 0.0                0.078652
# 1.0                0.795789

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

fig = plt.figure(figsize=(10,6))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Credit_History')
ax1.set_ylabel('Count of Applicants')
ax1.set_title("Applicants by Credit_History")
temp1.plot(kind = "bar")

ax2 = fig.add_subplot(122)
ax2.set_xlabel('Credit_History')
ax2.set_ylabel('probabily of getting loan')
ax2.set_title("probabily of getting loan by credit history")
temp2.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Credit_History'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
c_d=df.groupby(["Credit_History", "Gender"])

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
A=df.groupby(['Credit_History','Gender']).size()

# %%
sns.countplot(A, label = "Count")
plt.show()

# %%
A=sns.countplot(x='Credit_History',  hue='Loan_Status', data=df)

# %%
sns.countplot(x="Property_Area", data=df )
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %%
df["Property_Area"].value_counts(normalize = True)
# Out:
# Semiurban    0.379479
# Urban        0.328990
# Rural        0.291531
# Name: Property_Area, dtype: float64

# %%
df["Property_Area"].value_counts(normalize = True)*100
# Out:
# Semiurban    37.947883
# Urban        32.899023
# Rural        29.153094
# Name: Property_Area, dtype: float64

# %%
df["Property_Area"].value_counts(normalize = True).plot.bar(title ="Property_Area")
# Out:
# <AxesSubplot:title={'center':'Property_Area'}>

# %%
temp3 = pd.crosstab(df['Credit_History'],df['Loan_Status'])
temp3.plot(kind="bar", stacked=True, color=['red','blue'], grid=False)
# Out:
# <AxesSubplot:xlabel='Credit_History'>

# %%
temp4 = pd.crosstab(df["Credit_History"], df["Gender"])
temp4.plot(kind="bar", color = ["red", "blue"], grid = False)
# Out:
# <AxesSubplot:xlabel='Credit_History'>

# %%
pd.crosstab(df["Gender"], df["Loan_Status"])
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
pivote_for_gender= df.pivot_table(values='Loan_Status',index=['Credit_History','Gender'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean()) 

print(pivote_for_gender*100, "%")
# Out:
#                        Loan_Status
# Credit_History Gender
# 0.0            Female     5.882353
#                Male       8.695652
# 1.0            Female    76.190476
#                Male      80.366492 %

# %%
credit_gender= pd.crosstab(index=[df['Credit_History'],df['Gender']], columns=(df["Loan_Status"]))
credit_gender.plot(kind='bar', color = ["red", "blue"])
# Out:
# <AxesSubplot:xlabel='Credit_History,Gender'>

# %%
credit_percentage=credit_gender.div(credit_gender.sum(1).astype(float), axis=0)
credit_percentage.plot(kind="bar", color = ["cyan","yellow"])
# Out:
# <AxesSubplot:xlabel='Credit_History,Gender'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
#df.fillna(method="ffill")

# %%
#df.fillna(df['LoanAmount'].mean(), inplace=True)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.boxplot(column ='LoanAmount', by=['Education', 'Self_Employed'], figsize = (17,4))
# Out:
# <AxesSubplot:title={'center':'LoanAmount'}, xlabel='[Education, Self_Employed]'>

# %%
#df['LoanAmount'].fillna(df['LoanAmount'].mean(), inplace = True)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['Self_Employed'].value_counts(normalize=True)*100
# Out:
# No     85.910653
# Yes    14.089347
# Name: Self_Employed, dtype: float64

# %%
df['Self_Employed'].fillna("No", inplace = True)

# %%
df['Self_Employed'].value_counts(normalize = True)*100
# Out:
# No     86.644951
# Yes    13.355049
# Name: Self_Employed, dtype: float64

# %%
table=df.pivot_table(values='LoanAmount', index='Self_Employed' ,columns='Education', aggfunc=np.median)
table
# Out:
# Education      Graduate  Not Graduate
# Self_Employed
# No                130.0         113.0
# Yes               157.5         130.0

# %%
#Define function to return value of this pivot_table 
def fage(x): 
    return table.loc[x['Self_Employed'],x['Education']]
    
# Replace missing values

# %%
df['LoanAmount'].fillna(df[df['LoanAmount'].isnull()].apply(fage, axis=1), inplace=True)

# %%
df['LoanAmount_log'] = np.log(df['LoanAmount']) 
df['LoanAmount_log'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df['TotalIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df['TotalIncome_log'] = np.log(df['TotalIncome']) 
df['LoanAmount_log'].hist(bins=20, legend = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Building a Predictive Model in Python

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True) 
df['Married'].fillna(df['Married'].mode()[0],inplace=True) 
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)

df.head(4)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       130.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status  LoanAmount_log
# 0             1.0         Urban           Y        4.867534
# 1             1.0         Rural           N        4.852030
# 2             1.0         Urban           Y        4.189655
# ...

# %%
from sklearn.preprocessing import LabelEncoder 

var_mod = ['Loan_ID','Gender','Married','Dependents','Education','Self_Employed','Property_Area','Loan_Status']  
le = LabelEncoder() 

for i in var_mod: 
    df[i] = le.fit_transform(df[i]) 

df.dtypes
# Out:
# Loan_ID                int64
# Gender                 int64
# Married                int64
# Dependents             int64
# Education              int64
# Self_Employed          int64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int64
# Loan_Status            int64
# LoanAmount_log       float64
# TotalIncome          float64
# TotalIncome_log      float64
# dtype: object

# %%
#Import models from scikit learn module: 
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.tree import DecisionTreeClassifier, export_graphviz 
from sklearn import metrics

#For K-fold cross validation 
from sklearn.model_selection import KFold 


#Generic function for making a classification model and accessing performance: 
def classification_model(model, data, predictors, outcome): 
    
    #Fit the model:
    model.fit(data[predictors],data[outcome])                   
    
    #Make predictions on training set: 
    predictions = model.predict(data[predictors])                             
    #Print accuracy 
    accuracy = metrics.accuracy_score(predictions,data[outcome])
    print ("Accuracy : %s" % "{0:.3%}".format(accuracy)) 


    #Perform k-fold cross-validation with 5 folds 
    kf = KFold(n_splits=5)
    error = []
    for train, test in kf.split(data[predictors]):
        # Filter training data 
        train_predictors = (data[predictors].iloc[train,:])                 #The target we're using to train the algorithm. 
        train_target = data[outcome].iloc[train]                            #Training the algorithm using the predictors and target.
        model.fit(train_predictors, train_target)                           
        
        #Record error from each cross-validationrun   
        error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test])) 

    print ("Cross-ValidationScore : %s" % "{0:.3%}".format(np.mean(error)))     
    #Fit the model again so that it can be refered outside the function: 
    model.fit(data[predictors], data[outcome])

# %% [markdown]
# ## Logistic Regression

# %%
print(df.shape[0])
# Out:
# 614

# %%
outcome_var = ['Loan_Status'] 
model = LogisticRegression() 

predictor_var = ['Credit_History']
classification_model(model, df, predictor_var, outcome_var)
# Out:
# Accuracy : 80.945%
# Cross-ValidationScore : 80.946%

# %%
outcome_var = ['Loan_Status'] 
model = LogisticRegression() 

predictor_var =['Credit_History','Education','Married','Self_Employed','Property_Area'] 
classification_model(model, df, predictor_var, outcome_var)
# Out:
# Accuracy : 80.945%
# Cross-ValidationScore : 80.946%

# %% [markdown]
# ## Decision Tree

# %%
model = DecisionTreeClassifier() 
outcome_var = ['Loan_Status'] 
predictor_var = ['Credit_History']
classification_model(model, df, predictor_var,  outcome_var)
# Out:
# Accuracy : 80.945%
# Cross-ValidationScore : 80.946%

# %%
model = DecisionTreeClassifier() 
outcome_var = ['Loan_Status'] 
predictor_var = ['Credit_History','Gender','Married','Education','Property_Area']
classification_model(model, df, predictor_var,  outcome_var)
# Out:
# Accuracy : 81.270%
# Cross-ValidationScore : 80.458%

# %%
predictor_var =['Credit_History','Loan_Amount_Term','LoanAmount_log'] 
classification_model(model,df,predictor_var,outcome_var)
# Out:
# Accuracy : 88.925%
# Cross-ValidationScore : 69.374%

# %% [markdown]
# ## Random Forest

# %%
model = RandomForestClassifier(n_estimators=100)
predictor_var = ['Credit_History']
outcome_var = ['Loan_Status']
classification_model(model, df, predictor_var, outcome_var)
# Out:
# Accuracy : 80.945%
# Cross-ValidationScore : 80.946%

# %%
model = RandomForestClassifier(n_estimators=100)
outcome_var = ['Loan_Status'] 
predictor_var = ['Credit_History','Gender','Married','Education','Property_Area']
classification_model(model, df, predictor_var,  outcome_var)
# Out:
# Accuracy : 81.270%
# Cross-ValidationScore : 80.458%

# %%
model = RandomForestClassifier(n_estimators=100) 
predictor_var = ['Gender', 'Married', 'Dependents','Education', 'Self_Employed', 'Loan_Amount_Term','Credit_History', 'Property_Area','LoanAmount_log','TotalIncome_log'] 
classification_model(model, df,predictor_var,outcome_var)
# Out:
# Accuracy : 100.000%
# Cross-ValidationScore : 77.366%

# %% [markdown]
# #### The accuracy is 100% for the training set. This is the ultimate case of overfitting and can
#  ####        be resolved in two ways:
# 1. Reducing the number of predictors
# 2. Tuning the model parameters

# %%
#Create a series with feature importances: 

featimp = pd.Series(model.feature_importances_, index=predictor_var).sort_values(ascending=False) 
print (featimp*100)
# Out:
# TotalIncome_log     26.926465
# Credit_History      26.599992
# LoanAmount_log      22.708108
# Dependents           5.081425
# Property_Area        5.021551
# Loan_Amount_Term     4.392443
# Married              2.556577
# Self_Employed        2.308733
# Education            2.281321
# Gender               2.123385
# dtype: float64

# %%
model = RandomForestClassifier(n_estimators=25, min_samples_split=25, max_depth=7, max_features=1)
predictor_var = ['TotalIncome_log','LoanAmount_log','Credit_History','Dependents','Property_Area']
classification_model(model, df,predictor_var,outcome_var)
# Out:
# Accuracy : 82.736%
# Cross-ValidationScore : 80.620%
